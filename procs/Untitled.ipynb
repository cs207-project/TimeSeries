# %%
from interface import *

# %%
from _corr import ccor
import numpy as np
from timeseries import TimeSeries
# Out:
# Generating LALR tables

# %%
ts1 = TimeSeries(range(1,100,1),range(1,100,1))
ts2 = TimeSeries(range(100,10000,100),range(100,10000,100))
print( ts2)
# Out:
# [[ 100  200  300  400  500  600  700  800  900 1000 1100 1200 1300 1400
#   1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800
#   2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200
#   4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500 5600
#   5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900 7000
#   7100 7200 7300 7400 7500 7600 7700 7800 7900 8000 8100 8200 8300 8400
#   8500 8600 8700 8800 8900 9000 9100 9200 9300 9400 9500 9600 9700 9800
#   9900]
#  [ 100  200  300  400  500  600  700  800  900 1000 1100 1200 1300 1400
#   1500 1600 1700 1800 1900 2000 2100 2200 2300 2400 2500 2600 2700 2800
#   2900 3000 3100 3200 3300 3400 3500 3600 3700 3800 3900 4000 4100 4200
#   4300 4400 4500 4600 4700 4800 4900 5000 5100 5200 5300 5400 5500 5600
#   5700 5800 5900 6000 6100 6200 6300 6400 6500 6600 6700 6800 6900 7000
#   7100 7200 7300 7400 7500 7600 7700 7800 7900 8000 8100 8200 8300 8400
# ...

# %%
ts2
# Out:
# array([[ 100,  200,  300,  400,  500,  600,  700,  800,  900, 1000, 1100,
#         1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200,
#         2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300,
#         3400, 3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200, 4300, 4400,
#         4500, 4600, 4700, 4800, 4900, 5000, 5100, 5200, 5300, 5400, 5500,
#         5600, 5700, 5800, 5900, 6000, 6100, 6200, 6300, 6400, 6500, 6600,
#         6700, 6800, 6900, 7000, 7100, 7200, 7300, 7400, 7500, 7600, 7700,
#         7800, 7900, 8000, 8100, 8200, 8300, 8400, 8500, 8600, 8700, 8800,
#         8900, 9000, 9100, 9200, 9300, 9400, 9500, 9600, 9700, 9800, 9900],
#        [ 100,  200,  300,  400,  500,  600,  700,  800,  900, 1000, 1100,
#         1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900, 2000, 2100, 2200,
#         2300, 2400, 2500, 2600, 2700, 2800, 2900, 3000, 3100, 3200, 3300,
#         3400, 3500, 3600, 3700, 3800, 3900, 4000, 4100, 4200, 4300, 4400,
# ...

# %%
# %time
ccor(ts1,ts2)
# Out:
# CPU times: user 1 µs, sys: 1 µs, total: 2 µs
# Wall time: 4.05 µs
# array([ 6968.57463524,  3585.96414775,  3070.03269231,  3547.60591187,
#         3196.83330207,  2793.25629474,  3307.89975065,  3247.32449062,
#         2725.30149552,  3094.17306379,  3258.18006199,  2721.24282657,
#         2903.24534223,  3225.27422935,  2751.85485089,  2743.90402161,
#         3154.2176804 ,  2798.93238635,  2622.39256644,  3053.53537979,
#         2848.16669104,  2541.32691086,  2933.44923211,  2888.2401556 ,
#         2499.79616914,  2804.97782697,  2910.87066362,  2493.79277086,
#         2679.05844403,  2910.95576973,  2516.83041019,  2565.72036876,
#         2886.60151963,  2560.68875569,  2473.36347099,  2838.97242241,
#         2616.23151797,  2408.18886482,  2771.95298071,  2674.24314272,
#         2373.81635524,  2691.63792893,  2726.22928855,  2371.10984853,
#         2605.68478243,  2765.12917189,  2398.21781198,  2522.57314504,
# ...

# %%
pwd
# Out:
# '/Users/yuhantang/CS207/TimeSeries/procs'

# %%
ls
